# %% [markdown]
# ## Preliminaries

# %%
# pip install pandas matplotlib seaborn odfpy statsmodels

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import statsmodels.formula.api as smf
from scipy.stats import kendalltau, spearmanr

from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance, PartialDependenceDisplay
from sklearn.model_selection import LeaveOneOut, cross_val_predict

# %% [markdown]
# ## Workload and Results Loading

# %%
pm100_1 = pd.read_csv('workloads/pm100/pm100_1800_1.swf', header=None, sep='\t')
pm100_2 = pd.read_csv('workloads/pm100/pm100_1800_2.swf', header=None, sep='\t')
pm100_3 = pd.read_csv('workloads/pm100/pm100_1800_3.swf', header=None, sep='\t')
pm100_4 = pd.read_csv('workloads/pm100/pm100_1800_4.swf', header=None, sep='\t')
pm100_5 = pd.read_csv('workloads/pm100/pm100_1800_5.swf', header=None, sep='\t')

# %%
def load_results(path):
    """
    Load results from CSV or ODS file.
    Assumes decimals use '.' and columns are:
    workload, Policy, Estimation, awt, asd, ASU
    """
    if path.endswith(".csv"):
        df = pd.read_csv(path)
    elif path.endswith(".ods"):
        df = pd.read_excel(path, engine="odf")
    else:
        raise ValueError("Unsupported file format")

    # Ensure numeric columns are floats
    numeric_cols = ["AWT", "ASD", "ASU"]
    df[numeric_cols] = df[numeric_cols].astype(float)

    return df

# %%
df = load_results('results/pm100_results_h.ods')

# %%
df
# Out:
#     Workload      Policy     Estimation      AWT     ASD        ASU
# 0    Heavy_1     1 - SJF       1 - User  1192.11  649.98  22.431428
# 1    Heavy_1     1 - SJF     2 - Actual   416.00    1.28  22.550386
# 2    Heavy_1     1 - SJF  3 - Heuristic   815.37  247.64  22.558244
# 3    Heavy_1     1 - SJF         4 - DT   616.15    8.82  22.462810
# 4    Heavy_1     1 - SJF        5 - RNP   796.35   93.97  22.300330
# ..       ...         ...            ...      ...     ...        ...
# 135  Heavy_5  4 - PRB-JR  3 - Heuristic  1288.10  416.32  43.634921
# 136  Heavy_5  4 - PRB-JR         4 - DT  1286.94  415.13  43.597063
# 137  Heavy_5  4 - PRB-JR        5 - RNP  1274.47  407.45  43.680142
# 138  Heavy_5  4 - PRB-JR        6 - KNN  1265.58  407.77  43.661657
# 139  Heavy_5  4 - PRB-JR        7 - LLM  1264.08  406.09  43.654363
#
# [140 rows x 6 columns]

# %% [markdown]
# ## Averages Computation

# %%
avg_runtime_h1 = np.mean(pm100_1[3])
avg_runtime_h2 = np.mean(pm100_2[3])
avg_runtime_h3 = np.mean(pm100_3[3])
avg_runtime_h4 = np.mean(pm100_4[3])
avg_runtime_h5 = np.mean(pm100_5[3])

# %%
max_runtime_h1 = np.max(pm100_1[3])
max_runtime_h2 = np.max(pm100_2[3])
max_runtime_h3 = np.max(pm100_3[3])
max_runtime_h4 = np.max(pm100_4[3])
max_runtime_h5 = np.max(pm100_5[3])

# %%
avg_nodes_h1 = np.mean(pm100_1[4])
avg_nodes_h2 = np.mean(pm100_2[4])
avg_nodes_h3 = np.mean(pm100_3[4])
avg_nodes_h4 = np.mean(pm100_4[4])
avg_nodes_h5 = np.mean(pm100_5[4])

# %%
max_nodes_h1 = np.max(pm100_1[4])
max_nodes_h2 = np.max(pm100_2[4])
max_nodes_h3 = np.max(pm100_3[4])
max_nodes_h4 = np.max(pm100_4[4])
max_nodes_h5 = np.max(pm100_5[4])

# %%
workload_stats = pd.DataFrame({
    "Workload": ["Heavy_1", "Heavy_2", "Heavy_3", "Heavy_4", "Heavy_5"],
    "avg_runtime": [avg_runtime_h1, avg_runtime_h2, avg_runtime_h3,
                    avg_runtime_h4, avg_runtime_h5],
    "avg_nodes": [avg_nodes_h1, avg_nodes_h2, avg_nodes_h3,
                  avg_nodes_h4, avg_nodes_h5],
    "max_runtime": [max_runtime_h1, max_runtime_h2, max_runtime_h3,
                    max_runtime_h4, max_runtime_h5],
    "max_nodes": [max_nodes_h1, max_nodes_h2, max_nodes_h3,
                  max_nodes_h4, max_nodes_h5]
})

summary_df = df.merge(workload_stats, on="Workload")

# %%
workload_stats
# Out:
#   Workload  avg_runtime  avg_nodes  max_runtime  max_nodes
# 0  Heavy_1  4197.695556   3.077222        86351        128
# 1  Heavy_2  4364.892222   3.238333        86323        128
# 2  Heavy_3  4160.086111   3.657222        86289        128
# 3  Heavy_4  4248.523889   3.669444        86328        128
# 4  Heavy_5  4745.008889   3.528333        86018        128

# %%
summary_df
# Out:
#     Workload      Policy     Estimation      AWT     ASD        ASU  \
# 0    Heavy_1     1 - SJF       1 - User  1192.11  649.98  22.431428
# 1    Heavy_1     1 - SJF     2 - Actual   416.00    1.28  22.550386
# 2    Heavy_1     1 - SJF  3 - Heuristic   815.37  247.64  22.558244
# 3    Heavy_1     1 - SJF         4 - DT   616.15    8.82  22.462810
# 4    Heavy_1     1 - SJF        5 - RNP   796.35   93.97  22.300330
# ..       ...         ...            ...      ...     ...        ...
# 135  Heavy_5  4 - PRB-JR  3 - Heuristic  1288.10  416.32  43.634921
# 136  Heavy_5  4 - PRB-JR         4 - DT  1286.94  415.13  43.597063
# 137  Heavy_5  4 - PRB-JR        5 - RNP  1274.47  407.45  43.680142
# 138  Heavy_5  4 - PRB-JR        6 - KNN  1265.58  407.77  43.661657
# 139  Heavy_5  4 - PRB-JR        7 - LLM  1264.08  406.09  43.654363
#
#      avg_runtime  avg_nodes  max_runtime  max_nodes
# 0    4197.695556   3.077222        86351        128
# 1    4197.695556   3.077222        86351        128
# 2    4197.695556   3.077222        86351        128
# 3    4197.695556   3.077222        86351        128
# 4    4197.695556   3.077222        86351        128
# ..           ...        ...          ...        ...
# 135  4745.008889   3.528333        86018        128
# 136  4745.008889   3.528333        86018        128
# 137  4745.008889   3.528333        86018        128
# 138  4745.008889   3.528333        86018        128
# 139  4745.008889   3.528333        86018        128
#
# [140 rows x 10 columns]

# %% [markdown]
# ### Workloads Averages

# %%
def avg_across_workloads(df):
    return (
        df
        .groupby(["Policy", "Estimation"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "asu_avg"
        })
    )

# %%
avg_w_1 = avg_across_workloads(df)
avg_w_1.columns = ["Policy", "Estimation", "AWT", "ASD", "ASU"]

# %%
def avg_by_workload(df):
    return (
        df
        .groupby(["Workload"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "asu_avg"
        })
    )

# %%
avg_w_2 = avg_by_workload(df)

# %%
avg_w_1
# Out:
#         Policy     Estimation       AWT      ASD        ASU
# 0      1 - SJF       1 - User  1777.458  962.840  31.362464
# 1      1 - SJF     2 - Actual   544.958    1.426  31.392775
# 2      1 - SJF  3 - Heuristic  1089.536  332.620  31.418550
# 3      1 - SJF         4 - DT   716.580   10.336  31.372247
# 4      1 - SJF        5 - RNP  1101.928  126.456  31.063255
# 5      1 - SJF        6 - KNN   994.452  303.360  31.415597
# 6      1 - SJF        7 - LLM   572.714    6.386  31.398926
# 7   2 - EASYBF       1 - User  1031.982  329.304  31.782579
# 8   2 - EASYBF     2 - Actual  1031.982  329.304  31.782579
# 9   2 - EASYBF  3 - Heuristic  1031.982  329.304  31.782579
# 10  2 - EASYBF         4 - DT  1031.622  329.302  31.782579
# 11  2 - EASYBF        5 - RNP  1017.070  326.902  31.858946
# 12  2 - EASYBF        6 - KNN  1031.982  329.304  31.782579
# 13  2 - EASYBF        7 - LLM  1031.982  329.304  31.782579
# 14  3 - PRB-JA       1 - User  1045.096  335.136  31.748089
# 15  3 - PRB-JA     2 - Actual  1028.926  329.646  31.753368
# 16  3 - PRB-JA  3 - Heuristic  1035.788  332.606  31.741805
# 17  3 - PRB-JA         4 - DT  1044.510  336.658  31.722413
# 18  3 - PRB-JA        5 - RNP  1033.612  333.046  31.746449
# 19  3 - PRB-JA        6 - KNN  1025.858  329.680  31.773614
# 20  3 - PRB-JA        7 - LLM  1030.506  329.488  31.747615
# 21  4 - PRB-JR       1 - User  1048.970  337.320  31.687744
# 22  4 - PRB-JR     2 - Actual  1035.776  332.810  31.747690
# 23  4 - PRB-JR  3 - Heuristic  1030.806  332.514  31.737283
# 24  4 - PRB-JR         4 - DT  1047.674  338.456  31.728202
# 25  4 - PRB-JR        5 - RNP  1034.820  333.254  31.761403
# 26  4 - PRB-JR        6 - KNN  1050.678  340.046  31.780057
# 27  4 - PRB-JR        7 - LLM  1046.862  337.220  31.763114

# %% [markdown]
# ### Policies Averages

# %%
def avg_across_policies(df):
    return (
        df
        .groupby(["Workload", "Estimation"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "ASU_avg"
        })
    )

# %%
avg_p_1 = avg_across_policies(df)
avg_p_1
# Out:
#    Workload     Estimation    awt_avg   asd_avg    ASU_avg
# 0   Heavy_1       1 - User   889.2025  358.1225  22.580022
# 1   Heavy_1     2 - Actual   692.6150  194.3475  22.620233
# 2   Heavy_1  3 - Heuristic   795.4275  257.2675  22.612745
# 3   Heavy_1         4 - DT   745.6850  197.5625  22.599102
# 4   Heavy_1        5 - RNP   791.0525  218.8750  22.553696
# 5   Heavy_1        6 - KNN   765.8875  249.0900  22.620469
# 6   Heavy_1        7 - LLM   697.5250  195.1100  22.615044
# 7   Heavy_2       1 - User  1012.8525  423.1200  27.819863
# 8   Heavy_2     2 - Actual   751.4750  208.4050  27.844187
# 9   Heavy_2  3 - Heuristic   874.3200  291.4525  27.877984
# 10  Heavy_2         4 - DT   762.5650  207.7525  27.861293
# 11  Heavy_2        5 - RNP   821.8175  233.3700  27.866830
# 12  Heavy_2        6 - KNN   851.3650  278.4175  27.862550
# 13  Heavy_2        7 - LLM   754.3500  207.6450  27.859823
# 14  Heavy_3       1 - User  1671.8800  653.4375  40.768067
# 15  Heavy_3     2 - Actual  1189.5625  311.5575  40.810954
# 16  Heavy_3  3 - Heuristic  1357.4800  413.0350  40.776068
# 17  Heavy_3         4 - DT  1272.9550  328.5350  40.793292
# 18  Heavy_3        5 - RNP  1416.6300  346.0575  40.738522
# 19  Heavy_3        6 - KNN  1380.4350  426.1325  40.843272
# 20  Heavy_3        7 - LLM  1201.3500  314.2200  40.838828
# 21  Heavy_4       1 - User  1074.6300  436.4625  23.529485
# 22  Heavy_4     2 - Actual   805.9600  220.9550  23.561612
# 23  Heavy_4  3 - Heuristic   934.0300  299.5525  23.557063
# 24  Heavy_4         4 - DT   833.7225  218.4450  23.551906
# 25  Heavy_4        5 - RNP   903.6300  256.7725  23.508968
# 26  Heavy_4        6 - KNN   895.6250  286.2050  23.562238
# 27  Heavy_4        7 - LLM   823.3825  227.7100  23.544156
# 28  Heavy_5       1 - User  1480.8175  584.6075  43.528658
# 29  Heavy_5     2 - Actual  1112.4400  306.2175  43.508529
# 30  Heavy_5  3 - Heuristic  1273.8825  397.4975  43.526411
# 31  Heavy_5         4 - DT  1185.5550  316.1450  43.451208
# 32  Heavy_5        5 - RNP  1301.1575  344.4975  43.369549
# 33  Heavy_5        6 - KNN  1235.4000  388.1425  43.551278
# 34  Heavy_5        7 - LLM  1125.9725  308.3125  43.507443

# %%
def avg_by_Policy(df):
    return (
        df
        .groupby(["Policy"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "ASU_avg"
        })
    )

# %%
avg_p_2 = avg_by_Policy(df)
avg_p_2
# Out:
#        Policy      awt_avg     asd_avg    ASU_avg
# 0     1 - SJF   971.089429  249.060571  31.346259
# 1  2 - EASYBF  1029.800286  328.960571  31.793489
# 2  3 - PRB-JA  1034.899429  332.322857  31.747622
# 3  4 - PRB-JR  1042.226571  335.945714  31.743642

# %% [markdown]
# ### Estimations Averages

# %%
def avg_across_Estimations(df):
    return (
        df
        .groupby(["Workload", "Policy"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "ASU_avg"
        })
    )

# %%
avg_e_1 = avg_across_Estimations(df)
avg_e_1
# Out:
#    Workload      Policy      awt_avg     asd_avg    ASU_avg
# 0   Heavy_1     1 - SJF   710.360000  174.435714  22.480243
# 1   Heavy_1  2 - EASYBF   785.390000  258.850000  22.647334
# 2   Heavy_1  3 - PRB-JA   787.981429  260.457143  22.645923
# 3   Heavy_1  4 - PRB-JR   789.065714  260.757143  22.627249
# 4   Heavy_2     1 - SJF   833.591429  229.057143  27.724531
# 5   Heavy_2  2 - EASYBF   811.421429  269.080000  27.933627
# 6   Heavy_2  3 - PRB-JA   844.311429  279.811429  27.878816
# 7   Heavy_2  4 - PRB-JR   841.387143  279.287143  27.887328
# 8   Heavy_3     1 - SJF  1320.661429  336.378571  40.183949
# 9   Heavy_3  2 - EASYBF  1349.605714  414.680000  41.061902
# 10  Heavy_3  3 - PRB-JA  1376.455714  421.948571  40.945307
# 11  Heavy_3  4 - PRB-JR  1376.301429  422.978571  40.991130
# 12  Heavy_4     1 - SJF   880.971429  228.614286  23.327977
# 13  Heavy_4  2 - EASYBF   871.094286  282.135714  23.668769
# 14  Heavy_4  3 - PRB-JA   901.645714  294.851429  23.605341
# 15  Heavy_4  4 - PRB-JR   929.705714  306.457143  23.578158
# 16  Heavy_5     1 - SJF  1109.862857  276.817143  43.014597
# 17  Heavy_5  2 - EASYBF  1331.490000  420.057143  43.655811
# 18  Heavy_5  3 - PRB-JA  1264.102857  404.545714  43.662721
# 19  Heavy_5  4 - PRB-JR  1274.672857  410.248571  43.634343

# %%
def avg_by_Estimation(df):
    return (
        df
        .groupby(["Estimation"], as_index=False)
        .agg({
            "AWT": "mean",
            "ASD": "mean",
            "ASU": "mean"
        })
        .rename(columns={
            "AWT": "awt_avg",
            "ASD": "asd_avg",
            "ASU": "ASU_avg"
        })
    )

# %%
avg_e_2 = avg_by_Estimation(df)
avg_e_2
# Out:
#       Estimation    awt_avg   asd_avg    ASU_avg
# 0       1 - User  1225.8765  491.1500  31.645219
# 1     2 - Actual   910.4105  248.2965  31.669103
# 2  3 - Heuristic  1047.0280  331.7610  31.670054
# 3         4 - DT   960.0965  253.6880  31.651360
# 4        5 - RNP  1046.8575  279.9145  31.607513
# 5        6 - KNN  1025.7425  325.5975  31.687961
# 6        7 - LLM   920.5160  250.5995  31.673059

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# ### Helpers

# %%
def plot_metrics(df, policy_name="SJF", image_path=""):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    # metrics = ['AWT', 'ASD', 'ASU']
    metrics = ['AWT', 'ASD']
    
    for i, metric in enumerate(metrics):
        ax = axes[i]
        metric_col = f"{metric}"
        
        # Calcolo soglia per il posizionamento del testo (20% del massimo)
        max_val = df[metric_col].max()
        threshold = max_val * 0.20

        # Soglia per l'orientamento del testo (vertical vs horizontal)
        orientation_threshold = 0
        
        # Normalizzazione per la colormap
        norm = plt.Normalize(df[metric_col].min(), df[metric_col].max())
        colors = plt.cm.RdYlGn_r(norm(df[metric_col]))

        # Creazione barre
        bars = ax.bar(df['Estimation'], df[metric_col], color=colors, alpha=0.8)

        # Aggiunta valori (Logica per centro barra e rotazione verticale)
        for bar in bars:
            yval = bar.get_height()
            
            # Determiniamo se il valore deve essere verticale (> 1000)
            rotation = 'vertical' if yval > orientation_threshold else 'horizontal'
            
            if yval < threshold:
                # Sopra la barra
                y_pos = yval + (max_val * 0.02)
                va_pos = 'bottom'
            else:
                # Al centro della barra
                y_pos = yval / 2
                va_pos = 'center'

            ax.text(
                bar.get_x() + bar.get_width()/2, 
                y_pos, 
                round(yval, 4), 
                ha='center', 
                va=va_pos, 
                rotation=rotation, # Applica rotazione verticale se > 1000
                color='black'
            )

        ax.set_title(f'{policy_name} - {metric.upper()}', fontsize=14)
        ax.set_ylabel(metric.upper())
        ax.grid(axis='y', linestyle='--', alpha=0.7)
        
        # Ruota le etichette X a 45 gradi per ogni subplot
        ax.tick_params(axis='x', labelrotation=45)

    plt.tight_layout()

    # Salvataggio opzionale
    if image_path:
        plt.savefig(image_path, dpi=300)
        print(f"Grafico salvato in: {image_path}")

    plt.show()

def plot_metrics_horizontal(df, policy_name="SJF", max_values=None, image_path=""):
    """
    max_values: dict opzionale, es: {'AWT': 5000, 'ASD': 200, 'ASU': 1}
    """
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    # metrics = ['AWT', 'ASD', 'ASU']
    metrics = ['AWT', 'ASD']
    
    for i, metric in enumerate(metrics):
        ax = axes[i]
        metric_col = f"{metric}"
        
        # 1. Gestione della scala fissa
        # Se max_values è fornito, usiamo quello, altrimenti usiamo il max del dataframe corrente
        current_max = df[metric_col].max()
        limit_val = max_values[metric] if (max_values and metric in max_values) else current_max
        
        # Soglia per il testo basata sul limite dell'asse (per coerenza visiva)
        threshold = limit_val * 0.20
        
        # Normalizzazione colori (sempre basata sui dati reali del DF)
        norm = plt.Normalize(df[metric_col].min(), df[metric_col].max())
        colors = plt.cm.RdYlGn_r(norm(df[metric_col]))

        # Creazione barre orizzontali
        bars = ax.barh(df['Estimation'], df[metric_col], color=colors, alpha=0.8)

        # 2. Impostazione del limite dell'asse X
        ax.set_xlim(0, limit_val)

        # Aggiunta valori numerici
        for bar in bars:
            xval = bar.get_width()
            
            # Se il valore eccede il limite (per errore), lo clip-piamo per il posizionamento
            display_x = min(xval, limit_val)
            
            if xval < threshold:
                x_pos = display_x + (limit_val * 0.02)
                ha_pos = 'left'
            else:
                x_pos = display_x / 2
                ha_pos = 'center'

            ax.text(
                x_pos, 
                bar.get_y() + bar.get_height()/2, 
                round(xval, 4), 
                ha=ha_pos, 
                va='center', 
                color='black',
                fontsize=11
            )

        ax.set_title(f'{metric.upper()}', fontsize=20, pad=20)
        ax.tick_params(axis='y', labelsize=14)
        ax.tick_params(axis='x', labelsize=14)
        
        ax.grid(axis='x', linestyle='--', alpha=0.4)
        
    plt.tight_layout()

    if image_path:
        plt.savefig(image_path, dpi=300, bbox_inches='tight')
        print(f"Grafico salvato in: {image_path}")

    plt.show()

# %% [markdown]
# ### Plots

# %%
plot_metrics_horizontal(avg_w_1[0:7], policy_name="SJF", max_values={'AWT': 1800, 'ASD': 1000, 'ASU': 100}, image_path="images/1800x980/bar_plot_sjf_M2.png")
# Out:
# Grafico salvato in: images/1800x980/bar_plot_sjf_M2.png

# %%
plot_metrics_horizontal(avg_w_1[7:14], policy_name="EASYBF", max_values={'AWT': 1800, 'ASD': 1000, 'ASU': 100}, image_path="images/1800x980/bar_plot_easy_M2.png")
# Out:
# Grafico salvato in: images/1800x980/bar_plot_easy_M2.png

# %%
plot_metrics_horizontal(avg_w_1[14:21], policy_name="PRB-JA", max_values={'AWT': 1800, 'ASD': 1000, 'ASU': 100}, image_path="images/1800x980/bar_plot_prb_M2.png")
# Out:
# Grafico salvato in: images/1800x980/bar_plot_prb_M2.png

# %%
plot_metrics_horizontal(avg_w_1[21:28], policy_name="PRB-JR", max_values={'AWT': 1800, 'ASD': 1000, 'ASU': 100})

# %% [markdown]
# ## Heatmaps

# %%
def heatmap_avg_across_workloads(avg_df, metric, approx=".2f", image_path=""):
    pivot = avg_df.pivot(
        index="Policy",
        columns="Estimation",
        values=f"{metric}"
    )

    plt.figure(figsize=(8, 4))
    sns.heatmap(pivot, annot=True, fmt=approx, cmap="RdYlGn_r", cbar=False)
    plt.title(f"{metric.upper()}")
    plt.xticks(rotation = 45)
    plt.yticks(rotation = 45)
    plt.tight_layout()

    # Salvataggio opzionale
    if image_path:
        plt.savefig(image_path, dpi=300)
        print(f"Grafico salvato in: {image_path}")

    plt.show()

# %%
avg_w_1
# Out:
#         Policy     Estimation       AWT      ASD        ASU
# 0      1 - SJF       1 - User  1777.458  962.840  31.362464
# 1      1 - SJF     2 - Actual   544.958    1.426  31.392775
# 2      1 - SJF  3 - Heuristic  1089.536  332.620  31.418550
# 3      1 - SJF         4 - DT   716.580   10.336  31.372247
# 4      1 - SJF        5 - RNP  1101.928  126.456  31.063255
# 5      1 - SJF        6 - KNN   994.452  303.360  31.415597
# 6      1 - SJF        7 - LLM   572.714    6.386  31.398926
# 7   2 - EASYBF       1 - User  1031.982  329.304  31.782579
# 8   2 - EASYBF     2 - Actual  1031.982  329.304  31.782579
# 9   2 - EASYBF  3 - Heuristic  1031.982  329.304  31.782579
# 10  2 - EASYBF         4 - DT  1031.622  329.302  31.782579
# 11  2 - EASYBF        5 - RNP  1017.070  326.902  31.858946
# 12  2 - EASYBF        6 - KNN  1031.982  329.304  31.782579
# 13  2 - EASYBF        7 - LLM  1031.982  329.304  31.782579
# 14  3 - PRB-JA       1 - User  1045.096  335.136  31.748089
# 15  3 - PRB-JA     2 - Actual  1028.926  329.646  31.753368
# 16  3 - PRB-JA  3 - Heuristic  1035.788  332.606  31.741805
# 17  3 - PRB-JA         4 - DT  1044.510  336.658  31.722413
# 18  3 - PRB-JA        5 - RNP  1033.612  333.046  31.746449
# 19  3 - PRB-JA        6 - KNN  1025.858  329.680  31.773614
# 20  3 - PRB-JA        7 - LLM  1030.506  329.488  31.747615
# 21  4 - PRB-JR       1 - User  1048.970  337.320  31.687744
# 22  4 - PRB-JR     2 - Actual  1035.776  332.810  31.747690
# 23  4 - PRB-JR  3 - Heuristic  1030.806  332.514  31.737283
# 24  4 - PRB-JR         4 - DT  1047.674  338.456  31.728202
# 25  4 - PRB-JR        5 - RNP  1034.820  333.254  31.761403
# 26  4 - PRB-JR        6 - KNN  1050.678  340.046  31.780057
# 27  4 - PRB-JR        7 - LLM  1046.862  337.220  31.763114

# %%
heatmap_avg_across_workloads(avg_w_1, "AWT", image_path="images/1800x980/heatmap_awt_M2.png")
# Out:
# Grafico salvato in: images/1800x980/heatmap_awt_M2.png

# %%
heatmap_avg_across_workloads(avg_w_1, "ASD", image_path="images/1800x980/heatmap_asd_M2.png")
# Out:
# Grafico salvato in: images/1800x980/heatmap_asd_M2.png

# %%
heatmap_avg_across_workloads(avg_w_1, "ASU", approx=".4f", image_path="images/1800x980/heatmap_asu_M2.png")
# Out:
# Grafico salvato in: images/1800x980/heatmap_asu_M2.png

# %% [markdown]
# ## Workload Statistics vs Averages-Across-Workloads

# %% [markdown]
# ### Correlation analysis

# %%
def correlation_with_workload_stats(df, workload_stats):
    merged = df.merge(workload_stats, on="Workload")

    correlations = merged[[
        "AWT", "ASD", "ASU", "avg_runtime", "avg_nodes", 
    ]].corr()

    return correlations

# %%
corr = correlation_with_workload_stats(df, workload_stats)
corr
# Out:
#                   AWT       ASD       ASU  avg_runtime  avg_nodes
# AWT          1.000000  0.845404  0.698303     0.217227   0.515025
# ASD          0.845404  1.000000  0.345539     0.122158   0.248986
# ASU          0.698303  0.345539  1.000000     0.544873   0.502399
# avg_runtime  0.217227  0.122158  0.544873     1.000000   0.089194
# avg_nodes    0.515025  0.248986  0.502399     0.089194   1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Workload Statistics vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Estimation Accuracy vs Scheduling Metrics

# %% [markdown]
# ### Metrics Loading

# %%
acc_df = pd.read_csv("results/pm100_metrics_h.csv")

# Keep only workloads used in scheduling
acc_df = acc_df[acc_df["Workload"].isin(["Heavy_1", "Heavy_2", "Heavy_3", "Heavy_4", "Heavy_5"])]

# %%
acc_df
# Out:
#    Workload     Estimation Average Error           MAE        EA         MAPE  \
# 0   Heavy_1       1 - User      15:21:09  55269.971111  0.112060  2897.062409
# 1   Heavy_1     2 - Actual      00:00:00      0.000000  1.000000     0.000000
# 2   Heavy_1  3 - Heuristic      01:00:39   3639.192222  0.261731    49.402722
# 3   Heavy_1         4 - DT      00:54:17   3257.497778  0.578933     3.900385
# 4   Heavy_1        5 - RNP      01:19:11   4751.209444  0.557447    15.649739
# 5   Heavy_1        6 - KNN      00:58:04   3484.447778  0.293895    94.641129
# 6   Heavy_1        7 - LLM      00:06:19    379.891667  0.692021     5.377507
# 7   Heavy_2       1 - User      15:30:02  55802.132852  0.111877  2941.715391
# 8   Heavy_2     2 - Actual      00:00:00      0.000000  1.000000     0.000000
# 9   Heavy_2  3 - Heuristic      01:01:47   3707.128405  0.265234    50.127792
# 10  Heavy_2         4 - DT      00:59:21   3561.952752  0.583804     2.349663
# 11  Heavy_2        5 - RNP      01:20:51   4851.139522  0.572458     9.767804
# 12  Heavy_2        6 - KNN      01:00:50   3650.962757  0.291497    95.400870
# 13  Heavy_2        7 - LLM      00:05:44    344.256809  0.690850     3.331857
# 14  Heavy_3       1 - User      15:30:44  55844.547222  0.108645  2916.716436
# 15  Heavy_3     2 - Actual      00:00:00      0.000000  1.000000     0.000000
# 16  Heavy_3  3 - Heuristic      01:03:14   3794.812222  0.250550    53.235357
# 17  Heavy_3         4 - DT      00:56:51   3411.355556  0.575792     4.018924
# 18  Heavy_3        5 - RNP      01:18:00   4680.285556  0.560927    11.077634
# 19  Heavy_3        6 - KNN      01:00:06   3606.802778  0.279025    94.027060
# 20  Heavy_3        7 - LLM      00:07:30    450.420000  0.686966     0.475893
# 21  Heavy_4       1 - User      15:31:23  55883.309444  0.111510  2934.539797
# 22  Heavy_4     2 - Actual      00:00:00      0.000000  1.000000     0.000000
# 23  Heavy_4  3 - Heuristic      01:04:28   3868.036111  0.256110    58.572430
# 24  Heavy_4         4 - DT      00:55:15   3315.725556  0.580131     2.975655
# 25  Heavy_4        5 - RNP      01:12:56   4376.065556  0.561895    11.861834
# 26  Heavy_4        6 - KNN      01:01:40   3700.677222  0.280320    91.297206
# 27  Heavy_4        7 - LLM      00:05:57    357.598889  0.701812     3.194179
# 28  Heavy_5       1 - User      15:37:38  56258.324444  0.114256  2933.599430
# 29  Heavy_5     2 - Actual      00:00:00      0.000000  1.000000     0.000000
# 30  Heavy_5  3 - Heuristic      01:10:51   4251.083889  0.255522    49.561933
# 31  Heavy_5         4 - DT      01:05:51   3951.101111  0.568762     3.940506
# 32  Heavy_5        5 - RNP      01:28:14   5294.223889  0.561844    10.408774
# 33  Heavy_5        6 - KNN      01:04:36   3876.342222  0.286755    92.196694
# 34  Heavy_5        7 - LLM      00:08:00    480.790556  0.688347     1.855000
#
#          TAU      MAE_OVER    MAE_UNDER    %_OVER  ...  MAE_UNDER_M  %_OVER_M  \
# 0  -0.436130  55269.971111     0.000000  1.000000  ...     0.000000  1.000000
# 1   1.000000      0.000000     0.000000  0.000000  ...     0.000000  0.000000
# 2   0.344976   2056.633333  8443.156600  0.750000  ...  1063.477778  0.551325
# 3   0.665942   3212.281654  4923.017493  0.430000  ...  1341.623762  0.486755
# 4   0.553779   8097.084570  4427.384835  0.374444  ...  1315.676871  0.500000
# 5   0.251806   2967.841549  5576.344173  0.788889  ...   700.520833  0.667219
# 6   0.772922    522.237381  1584.236842  0.407222  ...   308.566667  0.198675
# 7  -0.440851  55802.132852     0.000000  1.000000  ...     0.000000  1.000000
# 8   1.000000      0.000000     0.000000  0.000000  ...     0.000000  0.000000
# 9   0.316668   2056.024627  8621.257709  0.744858  ...  1014.533569  0.529118
# 10  0.678676   3420.570270  5444.846910  0.411340  ...  1220.118380  0.450915
# 11  0.571455   8471.170015  4465.409904  0.359644  ...  1078.397260  0.509151
# 12  0.239281   3131.199859  5721.991957  0.787104  ...   730.574163  0.637271
# 13  0.764891    619.893733   851.378238  0.408004  ...   397.704000  0.216306
# 14 -0.438152  55844.547222     0.000000  1.000000  ...     0.000000  1.000000
# 15  1.000000      0.000000     0.000000  0.000000  ...     0.000000  0.000000
# 16  0.306685   2137.035424  8882.571106  0.752778  ...  1006.669091  0.534570
# 17  0.655267   3504.075949  5040.687593  0.438889  ...  1269.778502  0.465430
# 18  0.545745   7954.173579  4440.967168  0.361667  ...  1204.750842  0.483980
# 19  0.233849   2948.798043  6347.807263  0.795000  ...   735.267677  0.649241
# 20  0.755208    501.086370  2265.211340  0.411667  ...   431.689655  0.215852
# 21 -0.426255  55883.309444     0.000000  1.000000  ...     0.000000  1.000000
# 22  1.000000      0.000000     0.000000  0.000000  ...     0.000000  0.000000
# 23  0.320602   2199.413284  9009.638009  0.752778  ...  1099.059055  0.562823
# 24  0.675148   3155.594203  5068.382979  0.421667  ...  1205.736508  0.452668
# 25  0.558342   7786.055728  3976.432961  0.358889  ...  1173.603448  0.492255
# 26  0.241888   3012.101754  6454.970027  0.791667  ...   693.951872  0.666093
# 27  0.755300    483.229050  1481.024876  0.397778  ...   394.462121  0.213425
# 28 -0.412503  56258.324444     0.000000  1.000000  ...     0.000000  1.000000
# 29  1.000000      0.000000     0.000000  0.000000  ...     0.000000  0.000000
# 30  0.355836   2310.507474  9957.406114  0.743333  ...   987.260700  0.553043
# 31  0.671482   3729.900000  6207.531108  0.450000  ...  1079.406040  0.469565
# 32  0.557595   8995.819133  5066.955267  0.371667  ...  1106.202206  0.511304
# 33  0.265437   3238.446466  6472.936639  0.793889  ...   626.227273  0.681739
# 34  0.768457    725.438411  1815.525714  0.419444  ...   411.239316  0.219130
#
#     %_UNDER_M  %_EXACT_M         MAE_L    MAE_OVER_L   MAE_UNDER_L  %_OVER_L  \
# 0    0.000000   0.000000  27822.577778  27822.577778      0.000000  1.000000
# 1    0.000000   1.000000      0.000000      0.000000      0.000000  0.000000
# 2    0.447020   0.001656  20028.544444   7916.666667  21129.624242  0.083333
# 3    0.501656   0.011589  19476.922222  12832.119048  21656.182482  0.233333
# 4    0.486755   0.013245  21003.700000  17128.126984  23289.603448  0.350000
# 5    0.317881   0.014901  12110.355556   8880.448276  12730.668874  0.161111
# 6    0.198675   0.602649   1900.344444   3970.900000   9056.689655  0.111111
# 7    0.000000   0.000000  26505.588571  26505.588571      0.000000  1.000000
# 8    0.000000   1.000000      0.000000      0.000000      0.000000  0.000000
# 9    0.470882   0.000000  21816.994286  12746.133333  22667.387500  0.085714
# 10   0.534110   0.014975  23633.160000  15611.666667  26166.263158  0.240000
# 11   0.485857   0.004992  23892.960000  20607.573770  25650.929825  0.348571
# 12   0.347754   0.014975  13205.160000  11380.379310  13567.616438  0.165714
# 13   0.207987   0.575707    804.525714   2125.538462   7544.000000  0.074286
# 14   0.000000   0.000000  28048.676471  28048.676471      0.000000  1.000000
# 15   0.000000   1.000000      0.000000      0.000000      0.000000  0.000000
# 16   0.463744   0.001686  22110.352941   8406.750000  23151.132911  0.070588
# 17   0.517707   0.016863  21815.182353  14040.480769  25241.322034  0.305882
# 18   0.500843   0.015177  23667.611765  17837.453125  27187.707547  0.376471
# 19   0.333895   0.016863  14078.588235   9555.000000  14970.563380  0.164706
# 20   0.195616   0.588533   2920.123529   5129.619048  13882.107143  0.123529
# 21   0.000000   0.000000  27317.079787  27317.079787      0.000000  1.000000
# 22   0.000000   1.000000      0.000000      0.000000      0.000000  0.000000
# 23   0.437177   0.000000  20327.223404  10793.909091  20919.689266  0.058511
# 24   0.542169   0.005164  20206.329787  13554.511111  22299.559441  0.239362
# 25   0.499139   0.008606  20287.058511  17536.440000  22112.690265  0.398936
# 26   0.321859   0.012048  13641.877660  13047.560000  13733.030675  0.132979
# 27   0.227194   0.559380   1589.909574   2602.857143  11101.954545  0.111702
# 28   0.000000   0.000000  29023.540404  29023.540404      0.000000  1.000000
# 29   0.000000   1.000000      0.000000      0.000000      0.000000  0.000000
# 30   0.446957   0.000000  22415.106061  14643.333333  22785.190476  0.045455
# 31   0.518261   0.012174  22892.469697  13022.728814  27278.028986  0.297980
# 32   0.473043   0.015652  24327.813131  20686.897436  26694.408333  0.393939
# 33   0.306087   0.012174  12720.686869   9329.900000  13326.184524  0.151515
# 34   0.203478   0.577391   2016.045455   5434.708333  11197.666667  0.121212
#
#     %_UNDER_L  %_EXACT_L
# 0    0.000000   0.000000
# 1    0.000000   1.000000
# 2    0.916667   0.000000
# 3    0.761111   0.005556
# 4    0.644444   0.005556
# 5    0.838889   0.000000
# 6    0.161111   0.727778
# 7    0.000000   0.000000
# 8    0.000000   1.000000
# 9    0.914286   0.000000
# 10   0.760000   0.000000
# 11   0.651429   0.000000
# 12   0.834286   0.000000
# 13   0.085714   0.840000
# 14   0.000000   0.000000
# 15   0.000000   1.000000
# 16   0.929412   0.000000
# 17   0.694118   0.000000
# 18   0.623529   0.000000
# 19   0.835294   0.000000
# 20   0.164706   0.711765
# 21   0.000000   0.000000
# 22   0.000000   1.000000
# 23   0.941489   0.000000
# 24   0.760638   0.000000
# 25   0.601064   0.000000
# 26   0.867021   0.000000
# 27   0.117021   0.771277
# 28   0.000000   0.000000
# 29   0.000000   1.000000
# 30   0.954545   0.000000
# 31   0.696970   0.005051
# 32   0.606061   0.000000
# 33   0.848485   0.000000
# 34   0.121212   0.757576
#
# [35 rows x 30 columns]

# %%
summary_df = df.merge(
    acc_df,
    on=["Workload", "Estimation"],
    how="left"
)

# %%
summary_df
# Out:
#     Workload      Policy     Estimation      AWT     ASD        ASU  \
# 0    Heavy_1     1 - SJF       1 - User  1192.11  649.98  22.431428
# 1    Heavy_1     1 - SJF     2 - Actual   416.00    1.28  22.550386
# 2    Heavy_1     1 - SJF  3 - Heuristic   815.37  247.64  22.558244
# 3    Heavy_1     1 - SJF         4 - DT   616.15    8.82  22.462810
# 4    Heavy_1     1 - SJF        5 - RNP   796.35   93.97  22.300330
# ..       ...         ...            ...      ...     ...        ...
# 135  Heavy_5  4 - PRB-JR  3 - Heuristic  1288.10  416.32  43.634921
# 136  Heavy_5  4 - PRB-JR         4 - DT  1286.94  415.13  43.597063
# 137  Heavy_5  4 - PRB-JR        5 - RNP  1274.47  407.45  43.680142
# 138  Heavy_5  4 - PRB-JR        6 - KNN  1265.58  407.77  43.661657
# 139  Heavy_5  4 - PRB-JR        7 - LLM  1264.08  406.09  43.654363
#
#     Average Error           MAE        EA         MAPE  ...  MAE_UNDER_M  \
# 0        15:21:09  55269.971111  0.112060  2897.062409  ...     0.000000
# 1        00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 2        01:00:39   3639.192222  0.261731    49.402722  ...  1063.477778
# 3        00:54:17   3257.497778  0.578933     3.900385  ...  1341.623762
# 4        01:19:11   4751.209444  0.557447    15.649739  ...  1315.676871
# ..            ...           ...       ...          ...  ...          ...
# 135      01:10:51   4251.083889  0.255522    49.561933  ...   987.260700
# 136      01:05:51   3951.101111  0.568762     3.940506  ...  1079.406040
# 137      01:28:14   5294.223889  0.561844    10.408774  ...  1106.202206
# 138      01:04:36   3876.342222  0.286755    92.196694  ...   626.227273
# 139      00:08:00    480.790556  0.688347     1.855000  ...   411.239316
#
#      %_OVER_M  %_UNDER_M  %_EXACT_M         MAE_L    MAE_OVER_L   MAE_UNDER_L  \
# 0    1.000000   0.000000   0.000000  27822.577778  27822.577778      0.000000
# 1    0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 2    0.551325   0.447020   0.001656  20028.544444   7916.666667  21129.624242
# 3    0.486755   0.501656   0.011589  19476.922222  12832.119048  21656.182482
# 4    0.500000   0.486755   0.013245  21003.700000  17128.126984  23289.603448
# ..        ...        ...        ...           ...           ...           ...
# 135  0.553043   0.446957   0.000000  22415.106061  14643.333333  22785.190476
# 136  0.469565   0.518261   0.012174  22892.469697  13022.728814  27278.028986
# 137  0.511304   0.473043   0.015652  24327.813131  20686.897436  26694.408333
# 138  0.681739   0.306087   0.012174  12720.686869   9329.900000  13326.184524
# 139  0.219130   0.203478   0.577391   2016.045455   5434.708333  11197.666667
#
#      %_OVER_L  %_UNDER_L  %_EXACT_L
# 0    1.000000   0.000000   0.000000
# 1    0.000000   0.000000   1.000000
# 2    0.083333   0.916667   0.000000
# 3    0.233333   0.761111   0.005556
# 4    0.350000   0.644444   0.005556
# ..        ...        ...        ...
# 135  0.045455   0.954545   0.000000
# 136  0.297980   0.696970   0.005051
# 137  0.393939   0.606061   0.000000
# 138  0.151515   0.848485   0.000000
# 139  0.121212   0.121212   0.757576
#
# [140 rows x 34 columns]

# %%
summary_df = summary_df.dropna()

# %% [markdown]
# ### Correlation Tables

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER", "%_OVER", "%_UNDER", "%_EXACT"
]

corr = summary_df[corr_cols].corr()

# %%
plt.figure(figsize=(8, 3))
sns.heatmap(corr.iloc[0:2, -9:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.savefig("images/1800x980/correlation_all_M2.png", dpi=300)
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

corr = summary_df[corr_cols].corr()

# %%
plt.figure(figsize=(11, 3))
sns.heatmap(corr.iloc[0:2, -15:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE", "MAPE", "EA", "TAU",
]

corr = summary_df[corr_cols].corr()

# %% [raw]
# plt.figure(figsize=(8, 6))
# sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=False)
# plt.title("Estimation Accuracy vs Scheduling Metrics")
# plt.tight_layout()
# plt.show()

# %%
plt.figure(figsize=(4, 2))
sns.heatmap(corr.iloc[0:2, -4:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE_OVER", "MAE_UNDER", "%_OVER", "%_UNDER", "%_EXACT"
]

corr = summary_df[corr_cols].corr()

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(corr.iloc[0:2, -5:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter plots: Accuracy → Performance

# %% [markdown]
# #### Data Preparation

# %%
summary_df
# Out:
#     Workload      Policy     Estimation      AWT     ASD        ASU  \
# 0    Heavy_1     1 - SJF       1 - User  1192.11  649.98  22.431428
# 1    Heavy_1     1 - SJF     2 - Actual   416.00    1.28  22.550386
# 2    Heavy_1     1 - SJF  3 - Heuristic   815.37  247.64  22.558244
# 3    Heavy_1     1 - SJF         4 - DT   616.15    8.82  22.462810
# 4    Heavy_1     1 - SJF        5 - RNP   796.35   93.97  22.300330
# ..       ...         ...            ...      ...     ...        ...
# 135  Heavy_5  4 - PRB-JR  3 - Heuristic  1288.10  416.32  43.634921
# 136  Heavy_5  4 - PRB-JR         4 - DT  1286.94  415.13  43.597063
# 137  Heavy_5  4 - PRB-JR        5 - RNP  1274.47  407.45  43.680142
# 138  Heavy_5  4 - PRB-JR        6 - KNN  1265.58  407.77  43.661657
# 139  Heavy_5  4 - PRB-JR        7 - LLM  1264.08  406.09  43.654363
#
#     Average Error           MAE        EA         MAPE  ...  MAE_UNDER_M  \
# 0        15:21:09  55269.971111  0.112060  2897.062409  ...     0.000000
# 1        00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 2        01:00:39   3639.192222  0.261731    49.402722  ...  1063.477778
# 3        00:54:17   3257.497778  0.578933     3.900385  ...  1341.623762
# 4        01:19:11   4751.209444  0.557447    15.649739  ...  1315.676871
# ..            ...           ...       ...          ...  ...          ...
# 135      01:10:51   4251.083889  0.255522    49.561933  ...   987.260700
# 136      01:05:51   3951.101111  0.568762     3.940506  ...  1079.406040
# 137      01:28:14   5294.223889  0.561844    10.408774  ...  1106.202206
# 138      01:04:36   3876.342222  0.286755    92.196694  ...   626.227273
# 139      00:08:00    480.790556  0.688347     1.855000  ...   411.239316
#
#      %_OVER_M  %_UNDER_M  %_EXACT_M         MAE_L    MAE_OVER_L   MAE_UNDER_L  \
# 0    1.000000   0.000000   0.000000  27822.577778  27822.577778      0.000000
# 1    0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 2    0.551325   0.447020   0.001656  20028.544444   7916.666667  21129.624242
# 3    0.486755   0.501656   0.011589  19476.922222  12832.119048  21656.182482
# 4    0.500000   0.486755   0.013245  21003.700000  17128.126984  23289.603448
# ..        ...        ...        ...           ...           ...           ...
# 135  0.553043   0.446957   0.000000  22415.106061  14643.333333  22785.190476
# 136  0.469565   0.518261   0.012174  22892.469697  13022.728814  27278.028986
# 137  0.511304   0.473043   0.015652  24327.813131  20686.897436  26694.408333
# 138  0.681739   0.306087   0.012174  12720.686869   9329.900000  13326.184524
# 139  0.219130   0.203478   0.577391   2016.045455   5434.708333  11197.666667
#
#      %_OVER_L  %_UNDER_L  %_EXACT_L
# 0    1.000000   0.000000   0.000000
# 1    0.000000   0.000000   1.000000
# 2    0.083333   0.916667   0.000000
# 3    0.233333   0.761111   0.005556
# 4    0.350000   0.644444   0.005556
# ..        ...        ...        ...
# 135  0.045455   0.954545   0.000000
# 136  0.297980   0.696970   0.005051
# 137  0.393939   0.606061   0.000000
# 138  0.151515   0.848485   0.000000
# 139  0.121212   0.121212   0.757576
#
# [140 rows x 34 columns]

# %%
summary_df_avg = (
    summary_df
    .groupby(["Policy", "Estimation"])
    .agg({
        "AWT": "mean",
        "ASD": "mean",
        "ASU": "mean",
        "MAE": "mean",
        "MAPE": "mean",
        "EA": "mean",
        "TAU": "mean"
    })
    .reset_index()
)

# %%
summary_df_no_user = summary_df[summary_df['Estimation'] != '1 - User']
summary_df_avg_no_user = summary_df_avg[summary_df_avg['Estimation'] != '1 - User']

# %% [markdown]
# #### Plots

# %%
def accuracy_vs_metric_by_policy(data, acc_metric, sched_metric):
    g = sns.FacetGrid(
        data,
        col="Policy",
        col_wrap=4,
        height=4,
        sharex=True,
        sharey=True
    )
    g.map_dataframe(
        sns.scatterplot,
        x=acc_metric,
        y=sched_metric,
        hue="Estimation",
        s=100
    )
    g.add_legend()
    g.set_titles("{col_name}")
    g.fig.suptitle(f"{sched_metric} vs {acc_metric} (by Policy)", y=1.05)
    plt.show()

# %%
accuracy_vs_metric_by_policy(summary_df_avg, "MAE", "AWT")
accuracy_vs_metric_by_policy(summary_df_avg, "MAE", "ASD")

accuracy_vs_metric_by_policy(summary_df_avg, "EA", "AWT")
accuracy_vs_metric_by_policy(summary_df_avg, "EA", "ASD")

accuracy_vs_metric_by_policy(summary_df_avg, "MAPE", "AWT")
accuracy_vs_metric_by_policy(summary_df_avg, "MAPE", "ASD")

accuracy_vs_metric_by_policy(summary_df_avg, "TAU", "AWT")
accuracy_vs_metric_by_policy(summary_df_avg, "TAU", "ASD")

# %% [markdown]
# ### Metrics Regression

# %% [markdown]
# #### Helpers

# %%
def plot_feature_importance(model, X, title):
    importances = model.feature_importances_
    indices = np.argsort(importances)

    plt.figure()
    plt.barh(range(len(indices)), importances[indices])
    plt.yticks(range(len(indices)), X.columns[indices])
    plt.xlabel("Importance")
    plt.title(title)
    plt.show()

# %%
def plot_permutation_importance(model, X, y, title):
    result = permutation_importance(
        model, X, y,
        n_repeats=30,
        random_state=42
    )

    sorted_idx = result.importances_mean.argsort()

    plt.figure()
    plt.barh(X.columns[sorted_idx], result.importances_mean[sorted_idx])
    plt.xlabel("Permutation Importance")
    plt.title(title)
    plt.show()

# %%
def plot_pdp(model, X, features, title, size=(12, 12)):
    fig, ax = plt.subplots(figsize=size)

    PartialDependenceDisplay.from_estimator(
        model,
        X,
        features,
        ax=ax
    )

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Random Forest - All Metrics

# %%
features = [
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER",
    "%_OVER", "%_UNDER", "%_EXACT",
        "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

X = summary_df[features]

# --- targets
y_awt = summary_df["AWT"]
y_asd = summary_df["ASD"]

# %%
rf_awt = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_asd = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_awt.fit(X, y_awt)
rf_asd.fit(X, y_asd)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
y_pred = rf_awt.predict(X)

plt.figure()
plt.scatter(y_awt, y_pred)
plt.xlabel("Actual AWT")
plt.ylabel("Predicted AWT")
plt.title("Predicted vs Actual")
plt.plot([y_awt.min(), y_awt.max()],
         [y_awt.min(), y_awt.max()])
plt.show()

# %%
y_pred = rf_asd.predict(X)

plt.figure()
plt.scatter(y_asd, y_pred)
plt.xlabel("Actual ASD")
plt.ylabel("Predicted ASD")
plt.title("Predicted vs Actual")
plt.plot([y_asd.min(), y_asd.max()],
         [y_asd.min(), y_asd.max()])
plt.show()

# %%
plot_feature_importance(rf_awt, X, "Feature Importance (AWT)")
plot_feature_importance(rf_asd, X, "Feature Importance (ASD)")

# %% [raw]
# plot_permutation_importance(rf_awt, X, y_awt, "Permutation Importance (AWT)")
# plot_permutation_importance(rf_asd, X, y_asd, "Permutation Importance (ASD)")

# %% [markdown]
# #### Random Forest - Reduced Metrics

# %%
features = [
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER",
    "%_OVER", "%_UNDER", "%_EXACT"]

X = summary_df[features]

# --- targets
y_awt = summary_df["AWT"]
y_asd = summary_df["ASD"]

# %%
rf_awt = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_asd = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_awt.fit(X, y_awt)
rf_asd.fit(X, y_asd)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
y_pred = rf_awt.predict(X)

plt.figure()
plt.scatter(y_awt, y_pred)
plt.xlabel("Actual AWT")
plt.ylabel("Predicted AWT")
plt.title("Predicted vs Actual")
plt.plot([y_awt.min(), y_awt.max()],
         [y_awt.min(), y_awt.max()])
plt.show()

# %%
y_pred = rf_asd.predict(X)

plt.figure()
plt.scatter(y_asd, y_pred)
plt.xlabel("Actual ASD")
plt.ylabel("Predicted ASD")
plt.title("Predicted vs Actual")
plt.plot([y_asd.min(), y_asd.max()],
         [y_asd.min(), y_asd.max()])
plt.show()

# %%
plot_feature_importance(rf_awt, X, "Feature Importance (AWT)")
plot_feature_importance(rf_asd, X, "Feature Importance (ASD)")

# %% [raw]
# plot_permutation_importance(rf_awt, X, y_awt, "Permutation Importance (AWT)")
# plot_permutation_importance(rf_asd, X, y_asd, "Permutation Importance (ASD)")

# %% [markdown]
# ## SJF-specific Analysis

# %% [markdown]
# ### Data Preprocessing

# %%
summary_df_sjf = summary_df[summary_df["Policy"] == "1 - SJF"]

# %%
summary_df_sjf
# Out:
#     Workload   Policy     Estimation      AWT      ASD        ASU  \
# 0    Heavy_1  1 - SJF       1 - User  1192.11   649.98  22.431428
# 1    Heavy_1  1 - SJF     2 - Actual   416.00     1.28  22.550386
# 2    Heavy_1  1 - SJF  3 - Heuristic   815.37   247.64  22.558244
# 3    Heavy_1  1 - SJF         4 - DT   616.15     8.82  22.462810
# 4    Heavy_1  1 - SJF        5 - RNP   796.35    93.97  22.300330
# 5    Heavy_1  1 - SJF        6 - KNN   702.35   216.00  22.528618
# 6    Heavy_1  1 - SJF        7 - LLM   434.19     3.36  22.529882
# 28   Heavy_2  1 - SJF       1 - User  1551.79   862.35  27.577079
# 29   Heavy_2  1 - SJF     2 - Actual   488.19     1.33  27.722784
# 30   Heavy_2  1 - SJF  3 - Heuristic  1019.64   341.72  27.762648
# 31   Heavy_2  1 - SJF         4 - DT   567.12     7.86  27.766391
# 32   Heavy_2  1 - SJF        5 - RNP   831.08   116.75  27.667229
# 33   Heavy_2  1 - SJF        6 - KNN   860.54   268.44  27.766391
# 34   Heavy_2  1 - SJF        7 - LLM   516.78     4.95  27.809197
# 56   Heavy_3  1 - SJF       1 - User  2501.05  1332.74  40.320570
# 57   Heavy_3  1 - SJF     2 - Actual   689.93     1.70  40.245658
# 58   Heavy_3  1 - SJF  3 - Heuristic  1372.62   416.16  40.245658
# 59   Heavy_3  1 - SJF         4 - DT   886.53    13.17  40.373306
# 60   Heavy_3  1 - SJF        5 - RNP  1722.73   165.32  39.602823
# 61   Heavy_3  1 - SJF        6 - KNN  1370.98   421.71  40.245658
# 62   Heavy_3  1 - SJF        7 - LLM   700.79     3.85  40.253968
# 84   Heavy_4  1 - SJF       1 - User  1638.79   877.89  23.218694
# 85   Heavy_4  1 - SJF     2 - Actual   519.45     1.36  23.407557
# 86   Heavy_4  1 - SJF  3 - Heuristic  1026.04   311.12  23.379753
# 87   Heavy_4  1 - SJF         4 - DT   677.93     8.79  23.301417
# 88   Heavy_4  1 - SJF        5 - RNP   834.10   113.34  23.265299
# 89   Heavy_4  1 - SJF        6 - KNN   918.52   275.54  23.358550
# 90   Heavy_4  1 - SJF        7 - LLM   551.97    12.26  23.364567
# 112  Heavy_5  1 - SJF       1 - User  2003.55  1091.24  43.264552
# 113  Heavy_5  1 - SJF     2 - Actual   611.22     1.46  43.037491
# 114  Heavy_5  1 - SJF  3 - Heuristic  1214.01   346.46  43.146448
# 115  Heavy_5  1 - SJF         4 - DT   835.17    13.04  42.957311
# 116  Heavy_5  1 - SJF        5 - RNP  1325.38   142.90  42.480592
# 117  Heavy_5  1 - SJF        6 - KNN  1119.87   335.11  43.178767
# 118  Heavy_5  1 - SJF        7 - LLM   659.84     7.51  43.037018
#
#     Average Error           MAE        EA         MAPE  ...  MAE_UNDER_M  \
# 0        15:21:09  55269.971111  0.112060  2897.062409  ...     0.000000
# 1        00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 2        01:00:39   3639.192222  0.261731    49.402722  ...  1063.477778
# 3        00:54:17   3257.497778  0.578933     3.900385  ...  1341.623762
# 4        01:19:11   4751.209444  0.557447    15.649739  ...  1315.676871
# 5        00:58:04   3484.447778  0.293895    94.641129  ...   700.520833
# 6        00:06:19    379.891667  0.692021     5.377507  ...   308.566667
# 28       15:30:02  55802.132852  0.111877  2941.715391  ...     0.000000
# 29       00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 30       01:01:47   3707.128405  0.265234    50.127792  ...  1014.533569
# 31       00:59:21   3561.952752  0.583804     2.349663  ...  1220.118380
# 32       01:20:51   4851.139522  0.572458     9.767804  ...  1078.397260
# 33       01:00:50   3650.962757  0.291497    95.400870  ...   730.574163
# 34       00:05:44    344.256809  0.690850     3.331857  ...   397.704000
# 56       15:30:44  55844.547222  0.108645  2916.716436  ...     0.000000
# 57       00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 58       01:03:14   3794.812222  0.250550    53.235357  ...  1006.669091
# 59       00:56:51   3411.355556  0.575792     4.018924  ...  1269.778502
# 60       01:18:00   4680.285556  0.560927    11.077634  ...  1204.750842
# 61       01:00:06   3606.802778  0.279025    94.027060  ...   735.267677
# 62       00:07:30    450.420000  0.686966     0.475893  ...   431.689655
# 84       15:31:23  55883.309444  0.111510  2934.539797  ...     0.000000
# 85       00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 86       01:04:28   3868.036111  0.256110    58.572430  ...  1099.059055
# 87       00:55:15   3315.725556  0.580131     2.975655  ...  1205.736508
# 88       01:12:56   4376.065556  0.561895    11.861834  ...  1173.603448
# 89       01:01:40   3700.677222  0.280320    91.297206  ...   693.951872
# 90       00:05:57    357.598889  0.701812     3.194179  ...   394.462121
# 112      15:37:38  56258.324444  0.114256  2933.599430  ...     0.000000
# 113      00:00:00      0.000000  1.000000     0.000000  ...     0.000000
# 114      01:10:51   4251.083889  0.255522    49.561933  ...   987.260700
# 115      01:05:51   3951.101111  0.568762     3.940506  ...  1079.406040
# 116      01:28:14   5294.223889  0.561844    10.408774  ...  1106.202206
# 117      01:04:36   3876.342222  0.286755    92.196694  ...   626.227273
# 118      00:08:00    480.790556  0.688347     1.855000  ...   411.239316
#
#      %_OVER_M  %_UNDER_M  %_EXACT_M         MAE_L    MAE_OVER_L   MAE_UNDER_L  \
# 0    1.000000   0.000000   0.000000  27822.577778  27822.577778      0.000000
# 1    0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 2    0.551325   0.447020   0.001656  20028.544444   7916.666667  21129.624242
# 3    0.486755   0.501656   0.011589  19476.922222  12832.119048  21656.182482
# 4    0.500000   0.486755   0.013245  21003.700000  17128.126984  23289.603448
# 5    0.667219   0.317881   0.014901  12110.355556   8880.448276  12730.668874
# 6    0.198675   0.198675   0.602649   1900.344444   3970.900000   9056.689655
# 28   1.000000   0.000000   0.000000  26505.588571  26505.588571      0.000000
# 29   0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 30   0.529118   0.470882   0.000000  21816.994286  12746.133333  22667.387500
# 31   0.450915   0.534110   0.014975  23633.160000  15611.666667  26166.263158
# 32   0.509151   0.485857   0.004992  23892.960000  20607.573770  25650.929825
# 33   0.637271   0.347754   0.014975  13205.160000  11380.379310  13567.616438
# 34   0.216306   0.207987   0.575707    804.525714   2125.538462   7544.000000
# 56   1.000000   0.000000   0.000000  28048.676471  28048.676471      0.000000
# 57   0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 58   0.534570   0.463744   0.001686  22110.352941   8406.750000  23151.132911
# 59   0.465430   0.517707   0.016863  21815.182353  14040.480769  25241.322034
# 60   0.483980   0.500843   0.015177  23667.611765  17837.453125  27187.707547
# 61   0.649241   0.333895   0.016863  14078.588235   9555.000000  14970.563380
# 62   0.215852   0.195616   0.588533   2920.123529   5129.619048  13882.107143
# 84   1.000000   0.000000   0.000000  27317.079787  27317.079787      0.000000
# 85   0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 86   0.562823   0.437177   0.000000  20327.223404  10793.909091  20919.689266
# 87   0.452668   0.542169   0.005164  20206.329787  13554.511111  22299.559441
# 88   0.492255   0.499139   0.008606  20287.058511  17536.440000  22112.690265
# 89   0.666093   0.321859   0.012048  13641.877660  13047.560000  13733.030675
# 90   0.213425   0.227194   0.559380   1589.909574   2602.857143  11101.954545
# 112  1.000000   0.000000   0.000000  29023.540404  29023.540404      0.000000
# 113  0.000000   0.000000   1.000000      0.000000      0.000000      0.000000
# 114  0.553043   0.446957   0.000000  22415.106061  14643.333333  22785.190476
# 115  0.469565   0.518261   0.012174  22892.469697  13022.728814  27278.028986
# 116  0.511304   0.473043   0.015652  24327.813131  20686.897436  26694.408333
# 117  0.681739   0.306087   0.012174  12720.686869   9329.900000  13326.184524
# 118  0.219130   0.203478   0.577391   2016.045455   5434.708333  11197.666667
#
#      %_OVER_L  %_UNDER_L  %_EXACT_L
# 0    1.000000   0.000000   0.000000
# 1    0.000000   0.000000   1.000000
# 2    0.083333   0.916667   0.000000
# 3    0.233333   0.761111   0.005556
# 4    0.350000   0.644444   0.005556
# 5    0.161111   0.838889   0.000000
# 6    0.111111   0.161111   0.727778
# 28   1.000000   0.000000   0.000000
# 29   0.000000   0.000000   1.000000
# 30   0.085714   0.914286   0.000000
# 31   0.240000   0.760000   0.000000
# 32   0.348571   0.651429   0.000000
# 33   0.165714   0.834286   0.000000
# 34   0.074286   0.085714   0.840000
# 56   1.000000   0.000000   0.000000
# 57   0.000000   0.000000   1.000000
# 58   0.070588   0.929412   0.000000
# 59   0.305882   0.694118   0.000000
# 60   0.376471   0.623529   0.000000
# 61   0.164706   0.835294   0.000000
# 62   0.123529   0.164706   0.711765
# 84   1.000000   0.000000   0.000000
# 85   0.000000   0.000000   1.000000
# 86   0.058511   0.941489   0.000000
# 87   0.239362   0.760638   0.000000
# 88   0.398936   0.601064   0.000000
# 89   0.132979   0.867021   0.000000
# 90   0.111702   0.117021   0.771277
# 112  1.000000   0.000000   0.000000
# 113  0.000000   0.000000   1.000000
# 114  0.045455   0.954545   0.000000
# 115  0.297980   0.696970   0.005051
# 116  0.393939   0.606061   0.000000
# 117  0.151515   0.848485   0.000000
# 118  0.121212   0.121212   0.757576
#
# [35 rows x 34 columns]

# %%
summary_df_sjf_avg = (
    summary_df_sjf
    .groupby(["Policy", "Estimation"])
    .agg({
        "AWT": "mean",
        "ASD": "mean",
        "ASU": "mean",
        "MAE": "mean",
        "MAPE": "mean",
        "EA": "mean",
        "TAU": "mean",
        "MAE_OVER": "mean",
        "MAE_UNDER": "mean",
        "%_OVER": "mean",
        "%_UNDER": "mean",
        "%_EXACT": "mean",
        "MAE_OVER_S": "mean", 
        "MAE_UNDER_S": "mean", 
        "%_OVER_S": "mean", 
        "%_UNDER_S": "mean", 
        "%_EXACT_S": "mean",
        "MAE_OVER_M": "mean", 
        "MAE_UNDER_M": "mean", 
        "%_OVER_M": "mean", 
        "%_UNDER_M": "mean", 
        "%_EXACT_M": "mean",
        "MAE_OVER_L": "mean", 
        "MAE_UNDER_L": "mean", 
        "%_OVER_L": "mean", 
        "%_UNDER_L": "mean", 
        "%_EXACT_L": "mean"
    })
    .reset_index()
)

# %%
summary_df_sjf_avg
# Out:
#     Policy     Estimation       AWT      ASD        ASU           MAE  \
# 0  1 - SJF       1 - User  1777.458  962.840  31.362464  55811.657015
# 1  1 - SJF     2 - Actual   544.958    1.426  31.392775      0.000000
# 2  1 - SJF  3 - Heuristic  1089.536  332.620  31.418550   3852.050570
# 3  1 - SJF         4 - DT   716.580   10.336  31.372247   3499.526550
# 4  1 - SJF        5 - RNP  1101.928  126.456  31.063255   4790.584793
# 5  1 - SJF        6 - KNN   994.452  303.360  31.415597   3663.846551
# 6  1 - SJF        7 - LLM   572.714    6.386  31.398926    402.591584
#
#           MAPE        EA       TAU      MAE_OVER  ...    MAE_OVER_M  \
# 0  2924.726692  0.111670 -0.430778  55811.657015  ...  33137.336595
# 1     0.000000  1.000000  1.000000      0.000000  ...      0.000000
# 2    52.180047  0.257829  0.328953   2151.922829  ...   2626.912486
# 3     3.437027  0.577484  0.669303   3404.484415  ...   4174.933675
# 4    11.753157  0.562914  0.557383   8260.860605  ...   7736.784873
# 5    93.512592  0.286298  0.246452   3059.677534  ...   2860.544538
# 6     2.846887  0.691999  0.763356    570.376989  ...   1297.160777
#
#    MAE_UNDER_M  %_OVER_M  %_UNDER_M  %_EXACT_M    MAE_OVER_L   MAE_UNDER_L  \
# 0     0.000000  1.000000   0.000000   0.000000  27743.492602      0.000000
# 1     0.000000  0.000000   0.000000   1.000000      0.000000      0.000000
# 2  1034.200039  0.546176   0.453156   0.000668  10901.358485  22130.604879
# 3  1223.332638  0.465067   0.522780   0.012153  13812.301282  24528.271220
# 4  1175.726125  0.499338   0.489128   0.011534  18759.298263  24987.067884
# 5   697.308363  0.660313   0.325495   0.014192  10438.657517  13665.612778
# 6   388.732352  0.212678   0.206590   0.580732   3852.724597  10556.483602
#
#    %_OVER_L  %_UNDER_L  %_EXACT_L
# 0  1.000000   0.000000   0.000000
# 1  0.000000   0.000000   1.000000
# 2  0.068720   0.931280   0.000000
# 3  0.263311   0.734567   0.002121
# 4  0.373584   0.625305   0.001111
# 5  0.155205   0.844795   0.000000
# 6  0.108368   0.129953   0.761679
#
# [7 rows x 29 columns]

# %%
predictions = pd.read_csv("predictions/pm100/predictions.csv")

w_1800_1 = pd.read_csv('workloads/pm100/pm100_1800_1.swf', sep="\t", header=None)
w_1800_2 = pd.read_csv('workloads/pm100/pm100_1800_2.swf', sep="\t", header=None)
w_1800_3 = pd.read_csv('workloads/pm100/pm100_1800_3.swf', sep="\t", header=None)
w_1800_4 = pd.read_csv('workloads/pm100/pm100_1800_4.swf', sep="\t", header=None)
w_1800_5 = pd.read_csv('workloads/pm100/pm100_1800_5.swf', sep="\t", header=None)

pred_w_1800_1 = predictions[predictions["job_id"].isin(w_1800_1[0].values)]
pred_w_1800_2 = predictions[predictions["job_id"].isin(w_1800_2[0].values)]
pred_w_1800_3 = predictions[predictions["job_id"].isin(w_1800_3[0].values)]
pred_w_1800_4 = predictions[predictions["job_id"].isin(w_1800_4[0].values)]
pred_w_1800_5 = predictions[predictions["job_id"].isin(w_1800_5[0].values)]

# %%
ESTIMATION_COL_MAP = {
    "1 - User": "pred_runtime_user",
    "3 - Heuristic": "pred_runtime_heuristic",
    "4 - DT": "pred_runtime_dt_fs2",
    "5 - RNP": "pred_runtime_rnp_fs2",
    "6 - KNN": "pred_runtime_knn_fs2",
    "7 - LLM": "pred_runtime_ora",
}

pred_dfs = {
    "Heavy_1": pred_w_1800_1,
    "Heavy_2": pred_w_1800_2,
    "Heavy_3": pred_w_1800_3,
    "Heavy_4": pred_w_1800_4,
    "Heavy_5": pred_w_1800_5,
}

# %%
job_rows = []

for workload, df in pred_dfs.items():
    for est_label, pred_col in ESTIMATION_COL_MAP.items():

        tmp = df[[
            "job_id",
            "user_id",
            "time_submit",
            "gt_runtime",
            pred_col
        ]].copy()

        tmp = tmp.rename(columns={
            pred_col: "predicted_runtime",
            "gt_runtime": "true_runtime"
        })

        tmp["Workload"] = workload
        tmp["Policy"] = "1 - SJF"
        tmp["Estimation"] = est_label

        job_rows.append(tmp)

job_df = pd.concat(job_rows, ignore_index=True)

# %%
job_df
# Out:
#         job_id  user_id  time_submit  true_runtime  predicted_runtime  \
# 0      5211156     1711     11480812          1568              14400
# 1       969923     1711     11480812          4550              14400
# 2      1664970     1711     11480812          4487              14400
# 3      4927366     1711     11480812          4477              14400
# 4      2762083      182     11507776           388               1800
# ...        ...      ...          ...           ...                ...
# 53989  1123770      666     13791306          4144               4144
# 53990  5363303        8     13807195             2                 20
# 53991  2441365     1242     13808952         22872              22872
# 53992  4125184        8     13822014             2                 20
# 53993  2220595     1352     13830246            46                 49
#
#       Workload   Policy Estimation
# 0      Heavy_1  1 - SJF   1 - User
# 1      Heavy_1  1 - SJF   1 - User
# 2      Heavy_1  1 - SJF   1 - User
# 3      Heavy_1  1 - SJF   1 - User
# 4      Heavy_1  1 - SJF   1 - User
# ...        ...      ...        ...
# 53989  Heavy_5  1 - SJF    7 - LLM
# 53990  Heavy_5  1 - SJF    7 - LLM
# 53991  Heavy_5  1 - SJF    7 - LLM
# 53992  Heavy_5  1 - SJF    7 - LLM
# 53993  Heavy_5  1 - SJF    7 - LLM
#
# [53994 rows x 8 columns]

# %%
job_df[["true_runtime", "predicted_runtime"]].describe()
# Out:
#        true_runtime  predicted_runtime
# count  53994.000000       53994.000000
# mean    4343.219135       13860.940697
# std    13516.283979       27356.438160
# min        1.000000           1.000000
# 25%        1.000000          21.000000
# 50%       48.000000        1510.000000
# 75%     1850.000000        6452.000000
# max    86351.000000       86400.000000

# %% [markdown]
# ### Correlation Tables

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER", "%_OVER", "%_UNDER", "%_EXACT"
]

corr = summary_df_sjf_avg[corr_cols].corr()

# %%
plt.figure(figsize=(8, 3))
sns.heatmap(corr.iloc[0:2, -9:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.savefig("images/1800x980/correlation_sjf_M2.png", dpi=300)
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

corr = summary_df_sjf_avg[corr_cols].corr()

# %%
plt.figure(figsize=(11, 3))
sns.heatmap(corr.iloc[0:2, -15:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE", "MAPE", "EA", "TAU"
]

corr = summary_df_sjf_avg[corr_cols].corr()

# %%
plt.figure(figsize=(4, 2))
sns.heatmap(corr.iloc[0:2, -4:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.savefig("images/1800x980/correlation_main_sjf_M2.png", dpi=300)
plt.show()

# %%
corr_cols = [
    "AWT", "ASD", # "ASU",
    "MAE_OVER", "MAE_UNDER", "%_OVER", "%_UNDER", "%_EXACT"
]

corr = summary_df_sjf[corr_cols].corr()

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(corr.iloc[0:2, -5:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD",
    "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S"
]

corr = summary_df_sjf[corr_cols].corr()

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(corr.iloc[0:2, -5:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M"
]

corr = summary_df_sjf[corr_cols].corr()

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(corr.iloc[0:2, -5:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %%
corr_cols = [
    "AWT", "ASD",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

corr = summary_df_sjf[corr_cols].corr()

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(corr.iloc[0:2, -5:], annot=True, cmap="coolwarm", fmt=".2f", cbar=False, vmin=-1, vmax=1)
plt.tick_params(axis='x', labelrotation=45)
plt.tick_params(axis='y', labelrotation=45)
plt.title("Estimation Accuracy vs Scheduling Metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter plots: Accuracy → Performance

# %%
def accuracy_vs_metrics_grid(data, acc_metrics, sched_metrics, size=(12, 12), image_path=""):
    fig, axes = plt.subplots(
        nrows=len(acc_metrics),
        ncols=len(sched_metrics),
        figsize=size,
        sharex=False,
        sharey=False
    )

    for i, acc_metric in enumerate(acc_metrics):
        for j, sched_metric in enumerate(sched_metrics):
            ax = axes[i, j]

            # Show legend only for last column
            show_legend = (j == len(sched_metrics) - 1)

            sns.scatterplot(
                data=data,
                x=acc_metric,
                y=sched_metric,
                hue="Estimation",
                s=50,
                ax=ax,
                legend=show_legend
            )

            ax.set_title(f"{sched_metric} vs {acc_metric}")
            ax.grid(True)

            # Move legend to the right of the last subplot
            if show_legend:
                handles, labels = ax.get_legend_handles_labels()
                ax.legend(
                    handles=handles,
                    labels=labels,
                    loc='center left',
                    bbox_to_anchor=(1.05, 0.5),
                    borderaxespad=0.
                )

    plt.tight_layout()

    # Add extra space on the right for legends
    plt.subplots_adjust(right=0.85)

    if image_path:
        plt.savefig(image_path, dpi=300, bbox_inches='tight')
        print(f"Grafico salvato in: {image_path}")

    plt.show()


import matplotlib.pyplot as plt
import seaborn as sns

def accuracy_vs_metrics_compact(data, acc_metrics, sched_metrics, size=(15, 5), image_path="", font_size=16):
    # Crea una copia per evitare di modificare il dataframe originale
    df_plot = data.copy()

    # 1. Normalizzazione MAE e MAPE tra 0 e 1 basata sul valore massimo
    for col in ["MAE", "MAPE"]:
        if col in df_plot.columns:
            max_val = df_plot[col].max()
            if max_val != 0:
                df_plot[col] = df_plot[col] / max_val

    # 1. Normalizzazione AWT e ASD basata sul valore minimo
    for col in ["AWT", "ASD"]:
        if col in df_plot.columns:
            min_val = df_plot[col].min()
            if min_val != 0:
                df_plot[col] = df_plot[col] / min_val

    # 2. Setup dei subplots: solo 2 colonne (una per ogni sched_metric)
    fig, axes = plt.subplots(
        nrows=1,
        ncols=len(sched_metrics),
        figsize=size,
        sharey=False
    )

    # Se c'è solo una sched_metric, axes non è una lista, lo rendiamo tale
    if len(sched_metrics) == 1:
        axes = [axes]

    # Definiamo dei marker specifici per le 4 acc_metrics
    marker_map = {"MAE": "o", "MAPE": "s", "EA": "D", "TAU": "X"}

    for j, sched_metric in enumerate(sched_metrics):
        ax = axes[j]
        
        # Trasformiamo il dataframe in "long format" per avere le acc_metrics come variabile
        df_melted = df_plot.melt(
            id_vars=["Estimation", sched_metric], 
            value_vars=acc_metrics, 
            var_name="Accuracy Metric", 
            value_name="Metric_Value"
        )

        sns.scatterplot(
            data=df_melted,
            x="Metric_Value",
            y=sched_metric,
            hue="Estimation",
            style="Accuracy Metric",
            markers=marker_map,
            s=100,  # Aumentato leggermente per abbinarsi ai font più grandi
            ax=ax,
            alpha=0.7
        )

        # 3. Limiti dei plot tra -1 e 1
        if "TAU" in acc_metrics:
            ax.set_xlim(-1, 1)
        else:
            ax.set_xlim(0, 1)
        
        # --- MODIFICHE DIMENSIONE TESTO ---
        # Titolo e Labels degli assi
        ax.set_title(f"Impact on {sched_metric}", fontsize=font_size + 2, pad=10)
        ax.set_xlabel("Normalized Metric Value", fontsize=font_size)
        ax.set_ylabel(sched_metric, fontsize=font_size)
        
        # Valori degli assi (Ticks)
        ax.tick_params(axis='both', which='major', labelsize=font_size)
        
        ax.grid(True, linestyle='--', alpha=0.6)

        # Gestione legenda
        if j == len(sched_metrics) - 1:
            # Modificati fontsize del testo e title_fontsize della legenda
            ax.legend(
                title="Legend", 
                bbox_to_anchor=(1.05, 1), 
                loc='upper left',
                fontsize=font_size,
                title_fontsize=font_size + 1
            )
        else:
            ax.get_legend().remove()

    plt.tight_layout()

    if image_path:
        plt.savefig(image_path, dpi=300, bbox_inches='tight')
        print(f"Grafico salvato in: {image_path}")

    plt.show()

# %%
acc_metrics = ["MAE", "MAPE", "EA", "TAU"]
sched_metrics = ["AWT", "ASD"]

accuracy_vs_metrics_grid(summary_df_sjf_avg, acc_metrics, sched_metrics, image_path="images/1800x980/scatter_plots_sjf_M2.png")
# Out:
# Grafico salvato in: images/1800x980/scatter_plots_sjf_M2.png

# %%
acc_metrics = ["MAE", "MAPE"]
sched_metrics = ["AWT", "ASD"]

# accuracy_vs_metrics_compact(summary_df_sjf_avg, acc_metrics, sched_metrics)
accuracy_vs_metrics_compact(summary_df_sjf_avg, acc_metrics, sched_metrics, image_path="images/1800x980/scatter_plots_sjf_M2_1.png")

acc_metrics = ["EA", "TAU"]
sched_metrics = ["AWT", "ASD"]

# accuracy_vs_metrics_compact(summary_df_sjf_avg, acc_metrics, sched_metrics)
accuracy_vs_metrics_compact(summary_df_sjf_avg, acc_metrics, sched_metrics, image_path="images/1800x980/scatter_plots_sjf_M2_2.png")
# Out:
# Grafico salvato in: images/1800x980/scatter_plots_sjf_M2_1.png
# Grafico salvato in: images/1800x980/scatter_plots_sjf_M2_2.png

# %% [raw]
# acc_metrics = ["MAE_OVER", "MAE_UNDER",     "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
#     "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
#     "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"]
#
# sched_metrics = ["AWT", "ASD"]
#
# accuracy_vs_metrics_grid(summary_df_sjf_avg, acc_metrics, sched_metrics, size=(12, 18))

# %%
acc_metrics = ["%_OVER", "%_UNDER", "%_EXACT"]
# sched_metrics = ["AWT", "ASD", "ASU"]
sched_metrics = ["AWT", "ASD"]

accuracy_vs_metrics_grid(summary_df_sjf_avg, acc_metrics, sched_metrics, size=(12, 9))

# %% [markdown]
# ### Rank–Rank Correlation

# %%
def rank_rank_correlation(summary_df, sched_metric, acc_metric, method_col="Estimation"):
    """
    summary_df: one row per estimation method (SJF only)
    """
    df = summary_df.copy()

    # Rank: lower scheduling metric is better, higher accuracy is better
    df["sched_rank"] = df[sched_metric].rank(ascending=True)
    df["acc_rank"] = df[acc_metric].rank(ascending=False)

    kendall = kendalltau(df["sched_rank"], df["acc_rank"])
    spearman = spearmanr(df["sched_rank"], df["acc_rank"])

    return {
        "kendall_tau": kendall.correlation,
        "spearman_r": spearman.correlation
    }

# %%
print("AWT vs MAE")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "MAE"))
print("ASD vs MAE")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "MAE"))
print("AWT vs MAPE")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "MAPE"))
print("ASD vs MAPE")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "MAPE"))
print("AWT vs EA")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "EA"))
print("ASD vs EA")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "EA"))
print("AWT vs TAU")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "TAU"))
print("ASD vs TAU")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "TAU"))
# Out:
# AWT vs MAE
# {'kendall_tau': np.float64(-1.0), 'spearman_r': np.float64(-1.0)}
# ASD vs MAE
# {'kendall_tau': np.float64(-0.8095238095238096), 'spearman_r': np.float64(-0.8928571428571429)}
# AWT vs MAPE
# {'kendall_tau': np.float64(-0.7142857142857143), 'spearman_r': np.float64(-0.8571428571428573)}
# ASD vs MAPE
# {'kendall_tau': np.float64(-0.9047619047619049), 'spearman_r': np.float64(-0.9642857142857145)}
# AWT vs EA
# {'kendall_tau': np.float64(0.8095238095238096), 'spearman_r': np.float64(0.8928571428571429)}
# ASD vs EA
# {'kendall_tau': np.float64(1.0), 'spearman_r': np.float64(1.0)}
# AWT vs TAU
# {'kendall_tau': np.float64(0.7142857142857143), 'spearman_r': np.float64(0.8571428571428573)}
# ASD vs TAU
# {'kendall_tau': np.float64(0.9047619047619049), 'spearman_r': np.float64(0.9642857142857145)}

# %%
print("AWT vs MAE_OVER")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "MAE_OVER"))
print("ASD vs MAE_OVER")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "MAE_OVER"))
print("AWT vs MAE_UNDER")
print(rank_rank_correlation(summary_df_sjf_avg, "AWT", "MAE_UNDER"))
print("ASD vs MAE_UNDER")
print(rank_rank_correlation(summary_df_sjf_avg, "ASD", "MAE_UNDER"))
# Out:
# AWT vs MAE_OVER
# {'kendall_tau': np.float64(-0.7142857142857143), 'spearman_r': np.float64(-0.8571428571428573)}
# ASD vs MAE_OVER
# {'kendall_tau': np.float64(-0.5238095238095238), 'spearman_r': np.float64(-0.6785714285714287)}
# AWT vs MAE_UNDER
# {'kendall_tau': np.float64(-0.19518001458970663), 'spearman_r': np.float64(-0.14414999403128945)}
# ASD vs MAE_UNDER
# {'kendall_tau': np.float64(-0.39036002917941326), 'spearman_r': np.float64(-0.3243374865704013)}

# %% [markdown]
# ### Metrics Regression

# %% [markdown]
# #### Helpers

# %%
def plot_feature_importance(model, X, title):
    importances = model.feature_importances_
    indices = np.argsort(importances)

    plt.figure()
    plt.barh(range(len(indices)), importances[indices])
    plt.yticks(range(len(indices)), X.columns[indices])
    plt.xlabel("Importance")
    plt.title(title)
    plt.show()

def plot_combined_feature_importance(model1, model2, X, title1, title2, image_path=""):
    # Create a figure with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    
    models = [model1, model2]
    axes = [ax1, ax2]
    titles = [title1, title2]

    for model, ax, title in zip(models, axes, titles):
        importances = model.feature_importances_
        indices = np.argsort(importances)

        # Plot on the specific axis (ax) instead of plt
        ax.barh(range(len(indices)), importances[indices], color='skyblue', edgecolor='black')
        ax.set_yticks(range(len(indices)))
        ax.set_yticklabels(X.columns[indices])
        ax.set_xlabel("Importance")
        ax.set_title(title)

    plt.tight_layout()

    if image_path:
        plt.savefig(image_path, dpi=300)
        print(f"Grafico salvato in: {image_path}")
        
    plt.show()

# %%
def plot_permutation_importance(model, X, y, title):
    result = permutation_importance(
        model, X, y,
        n_repeats=30,
        random_state=42
    )

    sorted_idx = result.importances_mean.argsort()

    plt.figure()
    plt.barh(X.columns[sorted_idx], result.importances_mean[sorted_idx])
    plt.xlabel("Permutation Importance")
    plt.title(title)
    plt.show()

# %%
def plot_pdp(model, X, features, title, size=(12, 12)):
    fig, ax = plt.subplots(figsize=size)

    PartialDependenceDisplay.from_estimator(
        model,
        X,
        features,
        ax=ax
    )

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
def plot_loocv(y_true, y_pred, title, ylabel):
    plt.figure()
    plt.scatter(y_true, y_pred)
    plt.plot([y_true.min(), y_true.max()],
             [y_true.min(), y_true.max()])
    plt.xlabel("Actual")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
def bootstrap_importance(X, y, n_runs=200):
    importances = []

    for _ in range(n_runs):
        idx = np.random.choice(len(X), len(X), replace=True)
        X_sample = X.iloc[idx]
        y_sample = y.iloc[idx]

        rf = RandomForestRegressor(n_estimators=200)
        rf.fit(X_sample, y_sample)

        importances.append(rf.feature_importances_)

    importances = np.array(importances)

    return importances.mean(axis=0), importances.std(axis=0)

def plot_importance(mean_imp, std_imp, feature_names, title):
    plt.figure()
    plt.barh(feature_names, mean_imp, xerr=std_imp)
    plt.xlabel("Importance")
    plt.title(title)
    plt.show()

# %%
def scatter_plot(df, x_col, y_col):
    plt.figure()
    plt.scatter(df[x_col], df[y_col])
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(f"{y_col} vs {x_col}")
    plt.show()

# %% [markdown]
# #### Random Forest - All Metrics

# %% [raw]
# We are not trying to build a model to predict AWT/ASD, but rather trying to understand what drives them, therefore we don't really care about generalization.  For this reason, since we have a very small dataset, we can use it for both fit and predict.

# %%
features = [
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER",
    "%_OVER", "%_UNDER", "%_EXACT",
    "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

X = summary_df_sjf[features]

# --- targets
y_awt = summary_df_sjf["AWT"]
y_asd = summary_df_sjf["ASD"]

# %%
rf_awt = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_asd = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_awt.fit(X, y_awt)
rf_asd.fit(X, y_asd)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
y_pred = rf_awt.predict(X)

plt.figure()
plt.scatter(y_awt, y_pred)
plt.xlabel("Actual AWT")
plt.ylabel("Predicted AWT")
plt.title("Predicted vs Actual")
plt.plot([y_awt.min(), y_awt.max()],
         [y_awt.min(), y_awt.max()])
plt.tight_layout()
plt.savefig("images/1800x980/awt_regression_sjf_M2.png", dpi=300)
plt.show()

# %%
y_pred = rf_asd.predict(X)

plt.figure()
plt.scatter(y_asd, y_pred)
plt.xlabel("Actual ASD")
plt.ylabel("Predicted ASD")
plt.title("Predicted vs Actual")
plt.plot([y_asd.min(), y_asd.max()],
         [y_asd.min(), y_asd.max()])
plt.tight_layout()
plt.savefig("images/1800x980/asd_regression_sjf_M2.png", dpi=300)
plt.show()

# %%
plot_feature_importance(rf_awt, X, "Feature Importance (AWT)")
plot_feature_importance(rf_asd, X, "Feature Importance (ASD)")

# %%
plot_combined_feature_importance(rf_awt, rf_asd, X, "Feature Importance (AWT)", "Feature Importance (ASD)", "images/1800x980/feature_importance_sjf_M2.png")
# Out:
# Grafico salvato in: images/1800x980/feature_importance_sjf_M2.png

# %% [raw]
# plot_permutation_importance(rf_awt, X, y_awt, "Permutation Importance (AWT)")
# plot_permutation_importance(rf_asd, X, y_asd, "Permutation Importance (ASD)")

# %% [markdown]
# #### Random Forest - Reduced Metrics

# %%
features = [
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER",
    "%_OVER", "%_UNDER", "%_EXACT"]

X = summary_df_sjf[features]

# --- targets
y_awt = summary_df_sjf["AWT"]
y_asd = summary_df_sjf["ASD"]

# %%
rf_awt = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_asd = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    random_state=42
)

rf_awt.fit(X, y_awt)
rf_asd.fit(X, y_asd)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
y_pred = rf_awt.predict(X)

plt.figure()
plt.scatter(y_awt, y_pred)
plt.xlabel("Actual AWT")
plt.ylabel("Predicted AWT")
plt.title("Predicted vs Actual")
plt.plot([y_awt.min(), y_awt.max()],
         [y_awt.min(), y_awt.max()])
plt.show()

# %%
y_pred = rf_asd.predict(X)

plt.figure()
plt.scatter(y_asd, y_pred)
plt.xlabel("Actual ASD")
plt.ylabel("Predicted ASD")
plt.title("Predicted vs Actual")
plt.plot([y_asd.min(), y_asd.max()],
         [y_asd.min(), y_asd.max()])
plt.show()

# %%
plot_feature_importance(rf_awt, X, "Feature Importance (AWT)")
plot_feature_importance(rf_asd, X, "Feature Importance (ASD)")

# %% [raw]
# plot_permutation_importance(rf_awt, X, y_awt, "Permutation Importance (AWT)")
# plot_permutation_importance(rf_asd, X, y_asd, "Permutation Importance (ASD)")

# %% [raw]
# plot_pdp(rf_awt, X, features, "Partial Dependence (AWT)", size=(12,20))

# %% [raw]
# plot_pdp(rf_asd, X, features, "Partial Dependence (ASD)", size=(12,20))

# %% [raw]
# top_features_awt = X.columns[
#     np.argsort(rf_awt.feature_importances_)[-5:]
# ]
#
# plot_pdp(rf_awt, X, top_features_awt, "Partial Dependence (AWT)", size=(12,8))

# %% [raw]
# top_features_asd = X.columns[
#     np.argsort(rf_asd.feature_importances_)[-5:]
# ]
#
# plot_pdp(rf_asd, X, top_features_asd, "Partial Dependence (ASD)", size=(12,8))

# %% [markdown]
# #### Random Forest + LOO-CV

# %%
features = [
    "MAE", "MAPE", "EA", "TAU",
    "MAE_OVER", "MAE_UNDER",
    "%_OVER", "%_UNDER", "%_EXACT",
    "MAE_OVER_S", "MAE_UNDER_S", "%_OVER_S", "%_UNDER_S", "%_EXACT_S",
    "MAE_OVER_M", "MAE_UNDER_M", "%_OVER_M", "%_UNDER_M", "%_EXACT_M",
    "MAE_OVER_L", "MAE_UNDER_L", "%_OVER_L", "%_UNDER_L", "%_EXACT_L"
]

X = summary_df_sjf[features]

y_awt = summary_df_sjf["AWT"]
y_asd = summary_df_sjf["ASD"]

# %%
loo = LeaveOneOut()

rf_awt = RandomForestRegressor(n_estimators=300, random_state=42)
rf_asd = RandomForestRegressor(n_estimators=300, random_state=42)

# --- LOOCV predictions
y_pred_awt = cross_val_predict(rf_awt, X, y_awt, cv=loo)
y_pred_asd = cross_val_predict(rf_asd, X, y_asd, cv=loo)

# %%
plot_loocv(y_awt, y_pred_awt, "AWT Prediction (LOOCV)", "Predicted AWT")
plot_loocv(y_asd, y_pred_asd, "ASD Prediction (LOOCV)", "Predicted ASD")

# %%
mean_awt, std_awt = bootstrap_importance(X, y_awt)
mean_asd, std_asd = bootstrap_importance(X, y_asd)

plot_importance(mean_awt, std_awt, X.columns, "Feature Importance (AWT)")
plot_importance(mean_asd, std_asd, X.columns, "Feature Importance (ASD)")
